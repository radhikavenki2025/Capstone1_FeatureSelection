# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import time
import numpy as np

import encode
import quanqual
import EDA
import EDA1

import Capstone1_model

from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

# %%
st_habits = pd.read_csv('student_habits.csv')         # raw data

st_habits1 = st_habits.copy()

st_habits1
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
st_habits1 = encode.data_rename(st_habits1)

# %%
st_habits1 = encode.data_encoding(st_habits1)

# %%
st_habits1
# Out:
#      age  study_hrs  part_time_job  media_hrs  att_percent  sleep_hrs  \
# 0     23        0.0              0        2.3         85.0        8.0
# 1     20        6.9              0        5.1         97.3        4.6
# 2     21        1.4              0        4.4         94.8        8.0
# 3     23        1.0              0        4.9         71.0        9.2
# 4     19        5.0              0        4.9         90.9        4.9
# ..   ...        ...            ...        ...          ...        ...
# 995   21        2.6              0        2.1         77.0        7.5
# 996   17        2.9              1        3.4         86.0        6.8
# 997   20        3.0              0        3.9         61.9        6.5
# 998   24        5.4              1        5.2        100.0        7.6
# 999   19        4.3              0        4.8         89.4        7.1
#
#      diet_quality  exercise_fq  internet_quality  mental_health_rating  \
# ...

# %%
st_habits1['mental_health_warning'] = (st_habits1['mental_health_rating'] >= 3).astype(int)

### Defining the target variable : Mental health warning : Rating<=3 high risk 

st_habits1
# Out:
#      age  study_hrs  part_time_job  media_hrs  att_percent  sleep_hrs  \
# 0     23        0.0              0        2.3         85.0        8.0
# 1     20        6.9              0        5.1         97.3        4.6
# 2     21        1.4              0        4.4         94.8        8.0
# 3     23        1.0              0        4.9         71.0        9.2
# 4     19        5.0              0        4.9         90.9        4.9
# ..   ...        ...            ...        ...          ...        ...
# 995   21        2.6              0        2.1         77.0        7.5
# 996   17        2.9              1        3.4         86.0        6.8
# 997   20        3.0              0        3.9         61.9        6.5
# 998   24        5.4              1        5.2        100.0        7.6
# 999   19        4.3              0        4.8         89.4        7.1
#
#      diet_quality  exercise_fq  internet_quality  mental_health_rating  \
# ...

# %%
indep_X = st_habits1.drop(columns=['mental_health_rating','mental_health_warning'])

dep_Y = st_habits1['mental_health_warning']

# %%
indep_X
# Out:
#      age  study_hrs  part_time_job  media_hrs  att_percent  sleep_hrs  \
# 0     23        0.0              0        2.3         85.0        8.0
# 1     20        6.9              0        5.1         97.3        4.6
# 2     21        1.4              0        4.4         94.8        8.0
# 3     23        1.0              0        4.9         71.0        9.2
# 4     19        5.0              0        4.9         90.9        4.9
# ..   ...        ...            ...        ...          ...        ...
# 995   21        2.6              0        2.1         77.0        7.5
# 996   17        2.9              1        3.4         86.0        6.8
# 997   20        3.0              0        3.9         61.9        6.5
# 998   24        5.4              1        5.2        100.0        7.6
# 999   19        4.3              0        4.8         89.4        7.1
#
#      diet_quality  exercise_fq  internet_quality  extracurricular  exam_score  \
# ...

# %%
dep_Y
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 995    1
# 996    1
# 997    1
# 998    0
# 999    1
# Name: mental_health_warning, Length: 1000, dtype: int64

# %%
acclog=[]
accsvml=[]
accsvmnl=[]
accknn=[]
accnav=[]
accdes=[]
accrf=[]

kbest=Capstone1_model.selectkbest(indep_X,dep_Y,4) 

classifier = Capstone1_model.split_scalar(indep_X,dep_Y)
Capstone1_model.split_scalar(indep_X,dep_Y)
# Out:
# (array([[ 0.22548596,  2.17445014, -0.52695648, ..., -0.78509828,
#          -0.42992339, -0.32336595],
#         [-0.20703187,  1.41630571, -0.52695648, ...,  1.27372588,
#          -0.42992339, -0.32336595],
#         [-0.63954969, -1.27166094, -0.52695648, ..., -0.78509828,
#          -0.42992339, -0.32336595],
#         ...,
#         [ 1.09052161,  1.34738348,  1.89768991, ...,  1.27372588,
#          -0.42992339, -0.32336595],
#         [ 0.65800378, -0.5135165 , -0.52695648, ...,  1.27372588,
#          -0.42992339, -0.32336595],
#         [-1.50458534,  0.1067835 , -0.52695648, ..., -0.78509828,
#          -0.42992339, -0.32336595]], shape=(750, 18)),
#  array([[-0.20703187,  0.17570572, -0.52695648, ...,  1.27372588,
#          -0.42992339, -0.32336595],
#         [ 1.09052161, -1.34058316, -0.52695648, ...,  1.27372588,
#          -0.42992339, -0.32336595],
#         [ 0.22548596,  1.27846126, -0.52695648, ...,  1.27372588,
#          -0.42992339, -0.32336595],
# ...

# %%
X_train, X_test, y_train, y_test = Capstone1_model.split_scalar(kbest,dep_Y)   


classifier ,Accuracy,report,cm = Capstone1_model.logistic(X_train,y_train,X_test,y_test)
Capstone1_model.logistic(X_train,y_train,X_test,y_test)
acclog.append(Accuracy)

classifier ,Accuracy,report,cm  = Capstone1_model.svm_linear(X_train,y_train,X_test,y_test)
Capstone1_model.svm_linear(X_train,y_train,X_test,y_test)
accsvml.append(Accuracy)

classifier ,Accuracy,report,cm  = Capstone1_model.svm_NL(X_train, y_train,X_test,y_test)
Capstone1_model.svm_NL(X_train, y_train,X_test,y_test)
accsvmnl.append(Accuracy)

classifier ,Accuracy,report,cm = Capstone1_model.Navie(X_train,y_train,X_test,y_test)
Capstone1_model.Navie(X_train,y_train,X_test,y_test)
accnav.append(Accuracy)

classifier ,Accuracy,report,cm  = Capstone1_model.knn(X_train,y_train,X_test,y_test)
Capstone1_model.knn(X_train,y_train,X_test,y_test)
accknn.append(Accuracy)

classifier ,Accuracy,report,cm = Capstone1_model.Decision(X_train,y_train,X_test,y_test)
Capstone1_model.Decision(X_train,y_train,X_test,y_test)
accdes.append(Accuracy)

classifier ,Accuracy,report,cm  = Capstone1_model.random(X_train,y_train,X_test,y_test)
Capstone1_model.random(X_train,y_train,X_test,y_test)
accrf.append(Accuracy)


result = Capstone1_model.selectk_Classification(acclog,accsvml,accsvmnl,accknn,accnav,accdes,accrf)
# Out:
# /opt/anaconda3/envs/AIML/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/AIML/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/envs/AIML/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
result
# Out:
#           Logistic   SVMl  SVMnl   KNN  Navie Decision Random
# ChiSquare    0.812  0.816  0.816  0.78  0.764    0.688  0.724

# %%
selector = SelectKBest(score_func=chi2, k=4)
selector.fit(indep_X, dep_Y)
selected_cols = indep_X.columns[selector.get_support()]
print(selected_cols)
# Out:
# Index(['age', 'extracurricular', 'exam_score', 'par_edu_Master'], dtype='object')
